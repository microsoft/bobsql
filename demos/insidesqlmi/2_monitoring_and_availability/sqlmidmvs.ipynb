-- %% [markdown]
-- These popular DMVs work with SQL Server and Managed Instance

-- %%
select * from sys.dm_exec_requests;
go
select * from sys.dm_os_wait_stats;
go
select * from sys.dm_os_workers;
go
-- Out:
-- (115 rows affected)
-- (1362 rows affected)
-- (187 rows affected)
-- Total execution time: 00:00:00.155
-- ...

-- %% [markdown]
-- These DMVs are unique to Azure

-- %%
select * from sys.dm_instance_resource_governance;
go
select * from sys.dm_os_job_object;
go
select * from sys.server_resource_stats;
go
-- Out:
-- (1 row affected)
-- (1 row affected)
-- (256 rows affected)
-- (302 rows affected)
-- Total execution time: 00:00:01.001
-- ...
