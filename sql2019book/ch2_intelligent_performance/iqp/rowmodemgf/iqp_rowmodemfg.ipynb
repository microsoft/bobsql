-- %% [markdown]
-- # Intelligent Query Processing
-- ## Row Mode Memory Grant Feedback
-- Row Mode Memory Grant feedback is an example of Intelligent Query Processing that can be enabled by using dbcompat = 150. Follow the steps in this notebook to see the performance difference when the query optimizer recognizes a suboptimal memory grant and adapts dynamically.
--
-- **Prerequisites**: Restore the WideWorldImportersDW full backup. Then run the **extendwwidw.sql** script to customize the database. If you have already done this, proceed to the next steps

-- %% [markdown]
-- ## Step 1: Enable the database for row mode memory grant feedback
-- Change dbcompat to 150, clear the procedure cache, and ensure the buffer pool has warm cache for OrderHistory to make the query comparison fair.

-- %%
-- Step 1: Make sure this database is in compatibility level 150 and clear procedure cache for this database. Also bring the table into cache to compare warm cache queries
USE [WideWorldImportersDW]
GO
ALTER DATABASE [WideWorldImportersDW] SET COMPATIBILITY_LEVEL = 150
GO
ALTER DATABASE SCOPED CONFIGURATION CLEAR PROCEDURE_CACHE
GO
SELECT COUNT(*) FROM [Fact].[OrderHistory]
GO
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00.0011873
-- Commands completed successfully.
-- Total execution time: 00:00:00.0036616
-- Commands completed successfully.
-- Total execution time: 00:00:00.0038661
-- (1 row affected)
-- Total execution time: 00:00:00.2976729
-- <table><tr><th>(No column name)</th></tr><tr><td>3702592</td></tr></table>

-- %% [markdown]
-- ## Step 2: Simulate statistics out of sync or poor estimation
-- Let's use a little magic here to simulate that the statistics for the cardinality of the OrderHistory table doesn't match the actual cardinality.

-- %%
-- Step 2: Simulate statistics out of date
UPDATE STATISTICS Fact.OrderHistory 
WITH ROWCOUNT = 1000
GO
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00.0471979

-- %% [markdown]
-- ## Step 3: Run a typical data analytics query with joins
-- Run a query that gets order and stock item data. Force a hash join since it will need a memory grant. Since the optimizer thinks that OrderHistory only has 1000 rows it will under allocate memory for the grant causinmg a spill to disk, thus slowing down the query. Ignore the warning which just says we forced the type of join.

-- %%
SELECT fo.[Order Key], fo.Description,si.[Lead Time Days]
FROM  Fact.OrderHistory AS fo
INNER HASH JOIN Dimension.[Stock Item] AS si 
ON fo.[Stock Item Key] = si.[Stock Item Key]
WHERE fo.[Lineage Key] = 9
AND si.[Lead Time Days] > 19
GO
-- Out:
-- Warning: The join order has been enforced because a local join hint is used.
-- (66416 rows affected)
-- Total execution time: 00:00:29.6932207
-- Displaying Top 5000 rows.
-- <table><tr><th>Order Key</th><th>Description</th><th>Lead Time Days</th></tr><tr><td>3662222</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3662620</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3664585</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3693219</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3693222</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3693225</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3693230</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3693362</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3693363</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3693364</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3693365</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3693368</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3693371</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3693372</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3693373</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3693374</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3693377</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3693382</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3693387</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3693390</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3693670</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3693674</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3693675</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3693688</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3685802</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3683386</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3683387</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3683388</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3683389</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3683390</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3683391</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3683392</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3683393</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3683394</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3683395</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3683396</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3683397</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3683398</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3683399</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3683400</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3683401</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3683402</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3683403</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3683404</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3683405</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3677260</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3677498</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3677504</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3677567</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3678656</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3673805</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3673970</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3674978</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3674979</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3675015</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3668905</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3669756</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3564887</td><td>Tape dispenser (Black)</td><td>20</td></tr><tr><td>3565153</td><td>Tape dispense ...

-- %% [markdown]
-- ## Step 4: Run the query again.
-- This is the exact same query. This time the optimizer has recognized the grant was too small so will allocate a bigger grant and store it in the cached plan (but this information is not saved to disk). Notice again there are no comments in the cell so the query text is exactly the same. The query now should run signifanctly faster.

-- %%
SELECT fo.[Order Key], fo.Description,si.[Lead Time Days]
FROM  Fact.OrderHistory AS fo
INNER HASH JOIN Dimension.[Stock Item] AS si 
ON fo.[Stock Item Key] = si.[Stock Item Key]
WHERE fo.[Lineage Key] = 9
AND si.[Lead Time Days] > 19
GO
-- Out:
-- (66416 rows affected)
-- Total execution time: 00:00:02.9961746
-- Displaying Top 5000 rows.
-- <table><tr><th>Order Key</th><th>Description</th><th>Lead Time Days</th></tr><tr><td>226141</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>228959</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>202156</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>209868</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>213092</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>204431</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3702320</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3702376</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3700239</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3700399</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3700596</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3701194</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3701416</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3702137</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3699625</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3699723</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3699820</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3699872</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3699877</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3699994</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3698695</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3698721</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3699419</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3699443</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3699559</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3699560</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3698253</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3698260</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3698376</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3698441</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3698444</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3698491</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3697448</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3697613</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3697825</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3697845</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3697943</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3698219</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3697272</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3697290</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3697307</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3697311</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3697325</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3697409</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3696800</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3696901</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3697006</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3697055</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3697153</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3697205</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3696405</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3696443</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3696446</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3696532</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3696704</td><td>Air cushion machine (Blue)</td><td>20</td></tr><tr><td>3696737</td><td> ...

-- %% [markdown]
-- ## Step 5: Restore database to its previous state
-- Restore the statistics to their correct value and rebuild the index

-- %%
-- Step 5: Restore table and clustered index back to its original state
UPDATE STATISTICS Fact.OrderHistory 
WITH ROWCOUNT = 3702592
GO
ALTER TABLE [Fact].[OrderHistory] DROP CONSTRAINT [PK_Fact_OrderHistory]
GO
ALTER TABLE [Fact].[OrderHistory] ADD  CONSTRAINT [PK_Fact_OrderHistory] PRIMARY KEY NONCLUSTERED 
(
	[Order Key] ASC,
	[Order Date Key] ASC
)
GO
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00.0472133
-- Commands completed successfully.
-- Total execution time: 00:00:00.0049750
-- Commands completed successfully.
-- Total execution time: 00:00:01.2352462
